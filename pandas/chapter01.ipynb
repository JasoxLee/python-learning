# %%
import pandas as pd
df = pd.read_csv('./pandas/words.csv', index_col='Word')
df.head()
# Out:
#         Char Count  Value
# Word
# aa               2      2
# aah              3     10
# aahed            5     19
# aahing           6     40
# aahs             4     29

# %%
df.info()
df.shape
# df.loc[INDEX, COLMUN]
df.loc["microspectrophotometries"]
df.loc["microspectrophotometries", "Value"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 172823 entries, aa to zyzzyvas
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Char Count  172823 non-null  int64
#  1   Value       172823 non-null  int64
# dtypes: int64(2)
# memory usage: 4.0+ MB
# 317

# %%
df["Value"].max()
df.max()
df.describe()
# Out:
#           Char Count          Value
# count  172823.000000  172823.000000
# mean        9.087564     107.753441
# std         2.818334      39.317855
# min         2.000000       2.000000
# 25%         7.000000      80.000000
# 50%         9.000000     103.000000
# 75%        11.000000     131.000000
# max        28.000000     319.000000

# %%
df.loc[["pinfish","glowing","enfold","microbrew"]]
df.loc[["pinfish","glowing","enfold","microbrew"], 'Value']
# Out:
# Word
# pinfish       81
# glowing       87
# enfold        56
# microbrew    106
# Name: Value, dtype: int64

# %%
# sorting
df.sort_values(by='Value', ascending=False)

# conditional selection
df.loc[df['Value']==319]

df.loc[df['Value']==20]
# Out:
#         Char Count  Value
# Word
# able             4     20
# ado              3     20
# alfa             4     20
# ane              3     20
# as               2     20
# bale             4     20
# bide             4     20
# blae             4     20
# cabala           6     20
# cache            5     20
# cadge            5     20
# caged            5     20
# cake             4     20
# cap              3     20
# ceiba            5     20
# cel              3     20
# chi              3     20
# clad             4     20
# cob              3     20
# dagga            5     20
# dig              3     20
# facade           6     20
# facia            5     20
# faded            5     20
# feed             4     20
# fie              3     20
# gaff             4     20
# gage             4     20
# gal              3     20
# gid              3     20
# hebe             4     20
# hic              3     20
# ich              3     20
# jade             4     20
# jee              3     20
# lag              3     20
# nada             4     20
# nae              3     20
# oe               2     20
# pac              3     20

# %%
df['Value'].mode
# Out:
# <bound method Series.mode of Word
# aa             2
# aah           10
# aahed         19
# aahing        40
# aahs          29
#             ...
# zymotic      111
# zymurgies    143
# zymurgy      135
# zyzzyva      151
# zyzzyvas     170
# Name: Value, Length: 172823, dtype: int64>

# %%
df['Value'].value_counts().head()
# Out:
# Value
# 93     1965
# 100    1921
# 95     1915
# 99     1907
# 92     1902
# Name: count, dtype: int64

# %%
df.loc[df['Value'] == 93].head(10)
# Out:
#               Char Count  Value
# Word
# abandoners            10     93
# ablations              9     93
# aboiteaus              9     93
# abridgment            10     93
# abstracted            10     93
# acaulous               8     93
# accentuate            10     93
# accommodate           11     93
# accrediting           11     93
# acetaldehyde          12     93

# %%
df.loc[df['Value'] == 93].sample(10)
# Out:
#             Char Count  Value
# Word
# calipashes          10     93
# cruiser              7     93
# skaters              7     93
# holloaing            9     93
# enological          10     93
# hexagons             8     93
# burros               6     93
# tamandus             8     93
# exaggerate          10     93
# beclowns             8     93

# %%
df.loc[df['Value']==274].sort_values(by='Char Count')
# Out:
#                        Char Count  Value
# Word
# overprotectivenesses           20    274
# countercountermeasure          21    274
# psychophysiologically          21    274

# %%
df.loc[df['Value']==274, "Char Count"].min()
# Out:
# 20

# %%
df.loc[(df['Value']==274) & (df['Char Count'] == 20)]
# Out:
#                       Char Count  Value
# Word
# overprotectivenesses          20    274

# %%
df['Ratio'] = df['Value'] / df['Char Count']

# %%
df.head()
# Out:
#         Char Count  Value     Ratio
# Word
# aa               2      2  1.000000
# aah              3     10  3.333333
# aahed            5     19  3.800000
# aahing           6     40  6.666667
# aahs             4     29  7.250000

# %%
df.sort_values(by='Ratio', ascending=False).head()
# Out:
#        Char Count  Value      Ratio
# Word
# xu              2     45  22.500000
# muzzy           5    111  22.200000
# wry             3     66  22.000000
# xyst            4     88  22.000000
# tux             3     65  21.666667

# %%
del df['Radio']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/jupyterlab3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Radio'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 del df['Radio']
#
# File ~/miniforge3/envs/jupyterlab3.12/lib/python3.12/site-packages/pandas/core/generic.py:4506, in NDFrame.__delitem__(self, key)
#    4501             deleted = True
#    4502 if not deleted:
#    4503     # If the above loop ran and didn't delete anything because
#    4504     # there was no match, this call should raise the appropriate
#    4505     # exception:
# -> 4506     loc = self.axes[-1].get_loc(key)
#    4507     self._mgr = self._mgr.idelete(loc)
#    4509 # delete from the caches
#
# File ~/miniforge3/envs/jupyterlab3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Radio'

# %%
df.head()
# Out:
#         Char Count  Value     Ratio
# Word
# aa               2      2  1.000000
# aah              3     10  3.333333
# aahed            5     19  3.800000
# aahing           6     40  6.666667
# aahs             4     29  7.250000

# %%
df.loc[df['Ratio']==df['Ratio'].max()]
# Out:
#       Char Count  Value  Ratio
# Word
# xu             2     45   22.5

# %%
df['Ratio'].value_counts()
# Out:
# Ratio
# 12.000000    3751
# 11.000000    3428
# 13.000000    3272
# 10.000000    2604
# 14.000000    2357
#              ...
# 10.550000       1
# 8.944444        1
# 8.941176        1
# 9.263158        1
# 21.250000       1
# Name: count, Length: 1333, dtype: int64

# %%
df.loc[df['Ratio']==10].shape
# Out:
# (2604, 3)

# %%
df.index.shape
# Out:
# (172823,)

# %%
# query
df.query('Ratio == 10')
# Out:
#             Char Count  Value  Ratio
# Word
# aardwolf             8     80   10.0
# abatements          10    100   10.0
# abducts              7     70   10.0
# abetment             8     80   10.0
# abettals             8     80   10.0
# ...                ...    ...    ...
# ycleped              7     70   10.0
# yodeled              7     70   10.0
# zamia                5     50   10.0
# zebecs               6     60   10.0
# zwieback             8     80   10.0
#
# [2604 rows x 3 columns]

# %%
df.loc[df['Ratio']==10].sort_values(by='Value', ascending=False)
df.loc[df['Ratio']==10, 'Value'].max()
# Out:
# 240

# %%
df.loc[df['Value']==260].sort_values(by='Char Count')
df.loc[df['Value']==260, 'Char Count'].min()
df.loc[df['Value']==260].sort_values(by='Char Count')
# Out:
#                       Char Count  Value      Ratio
# Word
# hydroxytryptamine             17    260  15.294118
# neuropsychologists            18    260  14.444444
# psychophysiologist            18    260  14.444444
# revolutionarinesses           19    260  13.684211
# countermobilizations          20    260  13.000000
# underrepresentations          20    260  13.000000

# %%
mean_char_count = df['Char Count'].mean()
mean_char_count
# Out:
# 9.08756357660728

# %%
df.query("`Char Count` > @mean_char_count")
df.loc[df['Char Count'] > df['Char Count'].mean()]
# Out:
#               Char Count  Value      Ratio
# Word
# aardwolves            10    120  12.000000
# abacterial            10     72   7.200000
# abandoners            10     93   9.300000
# abandoning            10     81   8.100000
# abandonment           11    103   9.363636
# ...                  ...    ...        ...
# zygomorphies          12    176  14.666667
# zygomorphy            10    168  16.800000
# zygosities            10    154  15.400000
# zygospores            10    165  16.500000
# zymologies            10    146  14.600000
#
# [67582 rows x 3 columns]

# %%
# Out:
#               Char Count  Value      Ratio
# Word
# aardwolves            10    120  12.000000
# abacterial            10     72   7.200000
# abandoners            10     93   9.300000
# abandoning            10     81   8.100000
# abandonment           11    103   9.363636
# ...                  ...    ...        ...
# zygomorphies          12    176  14.666667
# zygomorphy            10    168  16.800000
# zygosities            10    154  15.400000
# zygospores            10    165  16.500000
# zymologies            10    146  14.600000
#
# [67582 rows x 3 columns]
